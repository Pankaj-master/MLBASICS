# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/panku/Downloads/newarea.csv")

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         3   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000

# %%
x = df[["area","bedrooms","age"]]

# %%
x
# Out:
#    area  bedrooms  age
# 0  2600         3   20
# 1  3000         4   15
# 2  3200         3   18
# 3  3600         3   30
# 4  4000         5    8

# %%
y = df.price

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# Name: price, dtype: int64

# %%
plt.title("Project 2")
plt.plot(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([   137.25, -26025.  ,  -6825.  ])

# %%
model.intercept_
# Out:
# 383724.9999999998

# %%
model.predict([[5000,3,5]])
# Out:
# D:\ANACONDA\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([957775.])

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         3   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000
